# %% [markdown]
# # Run Algorithms in OpenAI Gym

# %% [markdown]
# ## References

# %% [markdown]
# ## Preparation

# %% [markdown]
# > First, we need to install required system packages as well as PyPi packages. "Gym" is a package provided by OpenAI as a toolkit for developing reinforcement learning algorithm.

# %%
# %%capture
# !sudo apt update
# !sudo apt install python-opengl xvfb -y
# !pip install gym[box2d] piglet tqdm
#! pip install pyvirtualdisplay

# %% [markdown]
# > Clone the repository into colab notebook.

# %%
import os
# Remove existed repository which might be out of date.
os.chdir('/content')
# !rm -rf Exercises

# Clone the repository (branch vpg).
# !git clone -b vpg https://github.com/THCtw/Exercises.git
os.chdir('Exercises/Artificial Intelligence/openai-spinningup')
# Out:
# Cloning into 'Exercises'...
# remote: Enumerating objects: 191, done.
# remote: Counting objects: 100% (191/191), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 191 (delta 85), reused 169 (delta 66), pack-reused 0
# Receiving objects: 100% (191/191), 259.09 KiB | 7.40 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %% [markdown]
# ## Train

# %%
# %%capture
import gym
from algs.vpg.vpg import vpg as vpg
from algs.vpg import core

env = gym.make('LunarLander-v2')
vpg(lambda: env)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-997aa0d1b8ff> in <module>()
#       4
#       5 env = gym.make('LunarLander-v2')
# ----> 6 vpg(lambda: env)
#
# /content/Exercises/Artificial Intelligence/openai-spinningup/algs/vpg/vpg.py in vpg(env, record, policyAgent, gamma, seed, episodes_per_batch, num_batch)
#      44             while True:
#      45
# ---> 46                 action, log_prob = agent.sample(state)
#      47                 next_state, reward, done, _ = env.step(action)
#      48
#
# /content/Exercises/Artificial Intelligence/openai-spinningup/algs/vpg/core.py in sample(self, state)
#      79
#      80     def sample(self, state):
# ---> 81         action_prob = self.pgnet(torch.FloatTensor(state))
#      82         action_dist = Categorical(action_prob)
#      83         action = action_dist.sample()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /content/Exercises/Artificial Intelligence/openai-spinningup/algs/vpg/core.py in forward(self, state)
#      33         hid = torch.tanh(self.fc1(state))
#      34         hid = torch.tanh(self.fc2(hid))
# ---> 35         return F.softmax(self.fc3(hid), dim=-1)
#      36
#      37 class VFNet(nn.Module):
#
# NameError: name 'F' is not defined

# %% [markdown]
# ## Inference
