# %% [markdown]
# # Run Algorithms in OpenAI Gym

# %% [markdown]
# ## References

# %% [markdown]
# ## Preparation

# %% [markdown]
# > First, we need to install required system packages as well as PyPi packages. "Gym" is a package provided by OpenAI as a toolkit for developing reinforcement learning algorithm.

# %%
# %%capture
# !sudo apt update
# !sudo apt install python-opengl xvfb -y
# !pip install gym[box2d] piglet tqdm
#! pip install pyvirtualdisplay

# %% [markdown]
# > Clone the repository into colab notebook.

# %%
import os
# Remove existed repository which might be out of date.
os.chdir('/content')
# !rm -rf Exercises

# Clone the repository (branch vpg).
# !git clone -b vpg https://github.com/THCtw/Exercises.git
os.chdir('Exercises/Artificial Intelligence/openai-spinningup')
# Out:
# Cloning into 'Exercises'...
# remote: Enumerating objects: 199, done.
# remote: Counting objects: 100% (199/199), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 199 (delta 90), reused 175 (delta 69), pack-reused 0
# Receiving objects: 100% (199/199), 262.37 KiB | 8.75 MiB/s, done.
# Resolving deltas: 100% (90/90), done.

# %% [markdown]
# ## Train

# %%
# %%capture
import gym
from algs.vpg.vpg import vpg as vpg
from algs.vpg import core

if __name__ == '__main__':
    vpg(env = lambda: gym.make('LunarLander-v2'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-23084b23ccdc> in <module>()
#       4
#       5 if __name__ == '__main__':
# ----> 6     vpg(env = lambda: gym.make('LunarLander-v2'))
#
# /content/Exercises/Artificial Intelligence/openai-spinningup/algs/vpg/vpg.py in vpg(env, record, policyAgent, gamma, seed, episodes_per_batch, num_batch)
#      61                     states.append(episode_states)
#      62                     rewards.append(episode_rewards)
# ---> 63                     ret.append(core.discount_cumsum(rewards, gamma))
#      64                     break
#      65
#
# /content/Exercises/Artificial Intelligence/openai-spinningup/algs/vpg/core.py in discount_cumsum(x, discount)
#      21 		 x2]
#      22 	"""
# ---> 23         return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]
#      24
#      25 class PGNet(nn.Module):
#
# /usr/local/lib/python3.6/dist-packages/scipy/signal/signaltools.py in lfilter(b, a, x, axis, zi)
#    1881     else:
#    1882         if zi is None:
# -> 1883             return sigtools._linear_filter(b, a, x, axis)
#    1884         else:
#    1885             return sigtools._linear_filter(b, a, x, axis, zi)
#
# ValueError: could not convert b, a, and x to a common type

# %% [markdown]
# ## Inference
